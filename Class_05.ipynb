# %% [markdown]
# <a href="https://colab.research.google.com/github/Riturajsinha04/Python/blob/main/Class_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dct = {
    'name' : ['Anu', 'Riya', 'Suga', 'Jimin'],
    'age' : [22, 25, 32, 30],
    'roll' : [1, NaN, 3, 4]
}

dF = pd.DataFrame(dct)
dF1 = pd.DataFrame(dct)

display(dF)
display(dF1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1816/1098019036.py in <cell line: 0>()
#       2     'name' : ['Anu', 'Riya', 'Suga', 'Jimin'],
#       3     'age' : [22, 25, 32, 30],
# ----> 4     'roll' : [1, NaN, 3, 4]
#       5 }
#       6
#
# NameError: name 'NaN' is not defined

# %%
df = pd.read_csv('student_data.csv')
df
# print(df.head(3))
#print(df.tail(3)) # last 3 values
#print(df.shape) # rows and columns
#print(df.info) # dataframe metadata(file info - columns,datatypes,filetype)
#df.describe() - #statstical summary(mean.med,quartiles,std,min,max)
#df.columns - name of columns
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df[['study_hours','internet_usage']]
# Out:
#       study_hours  internet_usage
# 0               7               7
# 1               4               3
# 2              11               6
# 3               8               8
# 4               5               6
# ...           ...             ...
# 9995            2               7
# 9996            7               9
# 9997           10               5
# 9998           10               5
# 9999            2              11
#
# [10000 rows x 2 columns]

# %%
df.iloc[0]
# Out:
# study_hours                   7
# attendance                   56
# sleep_hours                   8
# internet_usage                7
# assignments_completed        10
# previous_score               62
# exam_score                100.0
# placement_status         Placed
# Name: 0, dtype: object

# %%
df.iloc[0:5]
# Out:
#    study_hours  attendance  sleep_hours  internet_usage  \
# 0            7          56            8               7
# 1            4          69            5               3
# 2           11          60            7               6
# 3            8          99            9               8
# 4            5          52            8               6
#
#    assignments_completed  previous_score  exam_score placement_status
# 0                     10              62      100.00           Placed
# 1                      8              56      100.00           Placed
# 2                     10              45      100.00           Placed
# 3                      4              55       90.17           Placed
# 4                      8              40       78.82           Placed

# %%
df.loc[df['study_hours']==11,['study_hours']]
# Out:
#       study_hours
# 2              11
# 9              11
# 10             11
# 29             11
# 30             11
# ...           ...
# 9969           11
# 9971           11
# 9978           11
# 9979           11
# 9988           11
#
# [868 rows x 1 columns]

# %%
df.loc[df['study_hours'] == 11, ['study_hours', 'sleep_hours']].iloc[4: 8]
# Out:
#      study_hours  sleep_hours
# 30            11            5
# 91            11            9
# 98            11            6
# 116           11            7

# %%
df.loc[4]
# Out:
# study_hours                   5
# attendance                   52
# sleep_hours                   8
# internet_usage                6
# assignments_completed         8
# previous_score               40
# exam_score                78.82
# placement_status         Placed
# Name: 4, dtype: object

# %%
df.loc[df["assignments_completed"] == 8].iloc[[1]]
# Out:
#    study_hours  attendance  sleep_hours  internet_usage  \
# 4            5          52            8               6
#
#    assignments_completed  previous_score  exam_score placement_status
# 4                      8              40       78.82           Placed

# %%
df[df["assignments_completed"] > 15]
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 8               7          72            8               5
# 12              5          52            6               9
# 22              2          47            8               2
# 23              5          88            6               3
# 28              1          44            9               1
# ...           ...         ...          ...             ...
# 9978           11          92            8               2
# 9979           11          78            9               5
# 9982            6          62            6               4
# 9983            6          92            6              10
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 8                        18              48       96.81           Placed
# 12                       17              89       95.36           Placed
# ...

# %%
df["age"] = 20
df
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status  age
# 0                        10              62      100.00           Placed   20
# 1                         8              56      100.00           Placed   20
# ...

# %%
df = df.rename(columns = {'assignments_completed' : 'assign_completed'})
df
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assign_completed  \
# 0               7          56            8               7                10
# 1               4          69            5               3                 8
# 2              11          60            7               6                10
# 3               8          99            9               8                 4
# 4               5          52            8               6                 8
# ...           ...         ...          ...             ...               ...
# 9995            2          58            9               7                 8
# 9996            7          98            6               9                 4
# 9997           10          44            8               5                10
# 9998           10          75            7               5                 8
# 9999            2          70            6              11                16
#
# ...

# %%
df.rename(columns = {'assignments_completed' : 'assign_completed'}, inplace = True)
print(df)
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assign_completed  \
# 0               7          56            8               7                10
# 1               4          69            5               3                 8
# 2              11          60            7               6                10
# 3               8          99            9               8                 4
# 4               5          52            8               6                 8
# ...           ...         ...          ...             ...               ...
# 9995            2          58            9               7                 8
# 9996            7          98            6               9                 4
# 9997           10          44            8               5                10
# 9998           10          75            7               5                 8
# 9999            2          70            6              11                16
#
# ...

# %%
df.drop(columns=["age"])
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assign_completed  \
# 0               7          56            8               7                10
# 1               4          69            5               3                 8
# 2              11          60            7               6                10
# 3               8          99            9               8                 4
# 4               5          52            8               6                 8
# ...           ...         ...          ...             ...               ...
# 9995            2          58            9               7                 8
# 9996            7          98            6               9                 4
# 9997           10          44            8               5                10
# 9998           10          75            7               5                 8
# 9999            2          70            6              11                16
#
# ...

# %%
df.dropna()
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assign_completed  \
# 0               7          56            8               7                10
# 1               4          69            5               3                 8
# 2              11          60            7               6                10
# 3               8          99            9               8                 4
# 4               5          52            8               6                 8
# ...           ...         ...          ...             ...               ...
# 9995            2          58            9               7                 8
# 9996            7          98            6               9                 4
# 9997           10          44            8               5                10
# 9998           10          75            7               5                 8
# 9999            2          70            6              11                16
#
# ...

# %%
df.sort_values(by="exam_score")
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assign_completed  \
# 8805            1          63            4              11                 6
# 186             1          47            5              10                 0
# 3141            1          55            8               8                 5
# 7566            1          58            7               3                 6
# 9499            2          64            5              10                 6
# ...           ...         ...          ...             ...               ...
# 0               7          56            8               7                10
# 1               4          69            5               3                 8
# 2              11          60            7               6                10
# 9993           10          86            9               9                15
# 9996            7          98            6               9                 4
#
# ...

# %%
df.sort_index()
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assign_completed  \
# 0               7          56            8               7                10
# 1               4          69            5               3                 8
# 2              11          60            7               6                10
# 3               8          99            9               8                 4
# 4               5          52            8               6                 8
# ...           ...         ...          ...             ...               ...
# 9995            2          58            9               7                 8
# 9996            7          98            6               9                 4
# 9997           10          44            8               5                10
# 9998           10          75            7               5                 8
# 9999            2          70            6              11                16
#
# ...

# %%
import numpy as np
dct = {
    'name' : ['Anu', 'Riya', 'Suga', 'Jimin'],
    'age' : [22, 25, 32, 30],
    'roll' : [1, np.nan, 3, 4]
}

dF = pd.DataFrame(dct)
dF
# Out:
#     name  age  roll
# 0    Anu   22   1.0
# 1   Riya   25   NaN
# 2   Suga   32   3.0
# 3  Jimin   30   4.0

# %%
dF.dropna()
# Out:
#     name  age  roll
# 0    Anu   22   1.0
# 2   Suga   32   3.0
# 3  Jimin   30   4.0

# %%
dF.isnull()
# Out:
#     name    age   roll
# 0  False  False  False
# 1  False  False   True
# 2  False  False  False
# 3  False  False  False

# %%
dF.notnull()
# Out:
#    name   age   roll
# 0  True  True   True
# 1  True  True  False
# 2  True  True   True
# 3  True  True   True

# %%
dF.fillna(2)
# Out:
#     name  age  roll
# 0    Anu   22   1.0
# 1   Riya   25   2.0
# 2   Suga   32   3.0
# 3  Jimin   30   4.0

# %%
dF["name"].unique()
# Out:
# array(['Anu', 'Riya', 'Suga', 'Jimin'], dtype=object)

# %%
dF.agg("sum")
# Out:
# name    AnuRiyaSugaJimin
# age                  109
# roll                 8.0
# dtype: object
