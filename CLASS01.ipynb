# %% [markdown]
# <a href="https://colab.research.google.com/github/Riturajsinha04/Python/blob/main/CLASS01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")

# %%
print("Hello Machines...")

# %%
a = 10
print(a * 2 + 5)

# %%
a = 5
b = 10
c = 15
d = 20
e = 25
print(a+b+c+d+e)

# %%
a = input()
b = input()
c = input()
print(a+b+c)

# %%
a = input()
b = input()
c = input()
print(a+b+c)

# %%
a = 1 * 10**9
b = 1 * 10**8
print(a+b)

# %%
a = 1
b = 5
print(a + b + c)

# %%
a = 10
b = 20
a, b = b , a
print (a, b)

# %%
for i in range(1, 51):
    if i % 2 == 0:
        print("Even no :", i)
    else:
        print("Odd no :", i)

# %%
a = 2
if a % 2 == 0:
  print("Even")
else :
  print("Odd")

# %%
a = 0
if a > 0:
  print("Positive")
elif a == 0:
  print("Zero")
else :
  print("Negative")

# %%
a = input()
if a == "Sun":
  print("Sunday")
elif a == "Mon":
  print("Monday")
elif a == "Tue":
  print("Tuesday")
else :
  print("Wednesday")

# %%
for i in range(0, 11, 2):
  print(i)

# %%
for i in range(1, 11, 2):
  print(i)

# %%
a = 0
while a < 10:
  print(a)
  a = a+1

# %%
s = input()
rev = ""
for ch in s:
  rev = ch + rev
if s == rev:
  print("Pallindrome")
else :
  print("Not A Pallindrome")
