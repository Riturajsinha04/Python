# %% [markdown]
# <a href="https://colab.research.google.com/github/Riturajsinha04/Python/blob/main/Class-02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fun_name(parameters):
    #body of the function
    pass

# %%
#To add two numbers
def add_(a,b):
    return(a + b)

# %%
# Lambda function
x = lambda a, b : b * a
print(x(2,3))
# Out:
# 6

# %%
#strings
st = ""
print(len(st))

st = "rituraj sinha"
st1 = st.upper()
print(st1)
# Out:
# 0
# RITURAJ SINHA

# %%
st = ""
print(len(st))

st = "RITURAJ SINHA"
st2 = st.lower()
print(st2)
# Out:
# 0
# rituraj sinha

# %%
st = ""
print(len(st))

st = "rituraj sinha"
st3 = st.title()
print(st3)
# Out:
# 0
# Rituraj Sinha

# %%
st = ""
print(len(st))

st = "rituraj sinha"
st4 = st.capitalize()
print(st4)
# Out:
# 0
# Rituraj sinha

# %%
st = "Ritu Raj Sinha"

st = st.strip('')
print(st)
# Out:
# Ritu Raj Sinha

# %%
first_name = "Ritu"
last_name = "Raj Sinha"

first_name = first_name.strip()
last_name = last_name.strip()

print(first_name +''+ last_name)
# Out:
# RituRaj Sinha

# %%
a = " today "
b = " weather "
c = " is GooD "
ans = a.strip().capitalize() + ", " + b.strip() + " " + c.strip().lower() + "."
print(ans)

ans.find("Today")
print(c.replace("GooD", "bad"))
# Out:
# Today, weather is good.
#  is bad

# %%
a = " today "
b = " weather "
c = "is GooD"
ans = a.strip().capitalize() + ", " + b.strip() + " " + c.strip().lower() + "."
print(ans)

ans.find("Today")
ans.find("is")
# Out:
# Today, weather is good.
# 15

# %%
a = " today "
b = " weather "
c = "is GooD"
ans = a.strip().capitalize() + ", " + b.strip() + " " + c.strip().lower() + "."
print(ans)

ans.startswith("Today")
ans.endswith("good")
# Out:
# Today, weather is good.
# False

# %%
a = "hello world"

print(a[6:11])
# Out:
# world

# %%
#Set

st = {43, 90, 21, 21, 45}

print(st)
# Out:
# {21, 90, 43, 45}

# %%
#Dictionary

d = {
    "name": ["Anushka", "Aaradhya", "Sankalp"],
    "age": 21,
    "occupation": "Student",
    "class": 10,
    "Roll No.": 16
}
# print(d['name'][0])

# d['id'] = 1234
# print(d)

del d["name"]
print(d)
# Out:
# {'age': 21, 'occupation': 'Student', 'class': 10, 'Roll No.': 16}
